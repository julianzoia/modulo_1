# %% [markdown]
# <a href="https://colab.research.google.com/github/julianzoia/modulo_1/blob/main/Colaboratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es mi primer cuaderno
# ##Aqui voy a mezclar código markdown con operaciones matemáticas
#
# - Sumar
# - Restar
# - Multiplicar
# - Dividir

# %%
a=3
b=5
a*b

a=1:100
b=a*a
plot(a,b, main = "prseion del gas critico", xlab="volumen" , ylab = "presion", type= "b", col = "blue")
# Out:
# [1] 15
# Plot with title “prseion del gas critico”
